# %%
# !pip install psycopg2
# Out:
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import psycopg2
# Out:
# /opt/conda/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
connection = psycopg2.connect(host='52.14.65.73', 
                              user='postgres', 
                              database='postgres')
cursor = connection.cursor()
cursor.execute("SELECT * FROM bc_data limit 5;")
results = cursor.fetchall()
connection.close()

# %%
results
# Out:
# [(1000025, 5, 1, 1, 1, 2, 1, 3, 1, 1, 2),
#  (1002945, 5, 4, 4, 5, 7, 10, 3, 2, 1, 2),
#  (1015425, 3, 1, 1, 1, 2, 2, 3, 1, 1, 2),
#  (1016277, 6, 8, 8, 1, 3, 4, 3, 7, 1, 2),
#  (1017023, 4, 1, 1, 3, 2, 1, 3, 1, 1, 2)]

# %%
from psycopg2.extras import RealDictCursor

# %%
connection = psycopg2.connect(host='52.14.65.73', 
                              user='postgres', 
                              database='postgres')
cursor = connection.cursor(cursor_factory=RealDictCursor)
cursor.execute("SELECT * FROM bc_data limit 5;")
results = cursor.fetchall()
connection.close()

# %%
results
# Out:
# [{'bare_nuclei': 1,
#   'bland_chromatin': 3,
#   'class': 2,
#   'clump_thickness': 5,
#   'marginal_adhesion': 1,
#   'mitoses': 1,
#   'normal_nucleoli': 1,
#   'sample_id': 1000025,
#   'single_epithelial_cell_size': 2,
#   'uniformity_of_cell_shape': 1,
#   'uniformity_of_cell_size': 1},
#  {'bare_nuclei': 10,
#   'bland_chromatin': 3,
#   'class': 2,
#   'clump_thickness': 5,
#   'marginal_adhesion': 5,
#   'mitoses': 1,
#   'normal_nucleoli': 2,
#   'sample_id': 1002945,
#   'single_epithelial_cell_size': 7,
#   'uniformity_of_cell_shape': 4,
#   'uniformity_of_cell_size': 4},
#  {'bare_nuclei': 2,
#   'bland_chromatin': 3,
#   'class': 2,
#   'clump_thickness': 3,
#   'marginal_adhesion': 1,
#   'mitoses': 1,
#   'normal_nucleoli': 1,
#   'sample_id': 1015425,
#   'single_epithelial_cell_size': 2,
#   'uniformity_of_cell_shape': 1,
#   'uniformity_of_cell_size': 1},
#  {'bare_nuclei': 4,
#   'bland_chromatin': 3,
#   'class': 2,
#   'clump_thickness': 6,
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(results)
# Out:
#    bare_nuclei  bland_chromatin  class  clump_thickness  marginal_adhesion  \
# 0            1                3      2                5                  1
# 1           10                3      2                5                  5
# 2            2                3      2                3                  1
# 3            4                3      2                6                  1
# 4            1                3      2                4                  3
#
#    mitoses  normal_nucleoli  sample_id  single_epithelial_cell_size  \
# 0        1                1    1000025                            2
# 1        1                2    1002945                            7
# 2        1                1    1015425                            2
# 3        1                7    1016277                            3
# 4        1                1    1017023                            2
#
#    uniformity_of_cell_shape  uniformity_of_cell_size
# ...

# %%
connection = psycopg2.connect(host='52.14.65.73', 
                              user='postgres', 
                              database='postgres')
cursor = connection.cursor(cursor_factory=RealDictCursor)
cursor.execute("SELECT COUNT(*) FROM bc_data limit 5;")
results = cursor.fetchall()
connection.close()

# %%
pd.DataFrame(results)
# Out:
#    count
# 0    699

# %%
connection = psycopg2.connect(host='52.14.65.73', 
                              user='postgres', 
                              database='postgres')
cursor = connection.cursor(cursor_factory=RealDictCursor)
cursor.execute("SELECT * FROM bc_data WHERE bare_nuclei >= 10;")
results = cursor.fetchall()
connection.close()

# %%
pd.DataFrame(results)
# Out:
#      bare_nuclei  bland_chromatin  class  clump_thickness  marginal_adhesion  \
# 0             10                3      2                5                  5
# 1             10                9      4                8                  8
# 2             10                3      2                1                  1
# 3             10                4      4               10                  6
# 4             10                5      4                7                 10
# 5             10                5      4                5                  9
# 6             10                7      4                6                  2
# 7             10                5      4                5                  1
# 8             10                4      4                5                  1
# 9             10                4      4                9                 10
# 10            10                6      4                3                  6
# ...

# %%
connection = psycopg2.connect(host='52.14.65.73', 
                              user='postgres', 
                              database='postgres')
cursor = connection.cursor(cursor_factory=RealDictCursor)
cursor.execute("\d+ bc_data;")
results = cursor.fetchall()
connection.close()
results
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-16-b60c366c6f00> in <module>()
#       3                               database='postgres')
#       4 cursor = connection.cursor(cursor_factory=RealDictCursor)
# ----> 5 cursor.execute("\d+ bc_data;")
#       6 results = cursor.fetchall()
#       7 connection.close()
#
# /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py in execute(self, query, vars)
#     247         self.column_mapping = []
#     248         self._query_executed = 1
# --> 249         return super(RealDictCursor, self).execute(query, vars)
#     250
#     251     def callproc(self, procname, vars=None):
#
# ProgrammingError: syntax error at or near "\"
# LINE 1: \d+ bc_data;
#         ^
